# %% [markdown]
# ### С файлами их всегда много
# ### Упражнение на списки и функции
# Дана строчка sequence с последовательностью натуральных чисел, разделенных пробелом. Посчитайте:
# 1. Количество четных и нечетных чисел в этой строке
# 2. Если четных больше, то укажите номер позиции первого "лишнего" нечетного числа
# 3. Если нечетных больше, то укажите позицию первого "лишнего" четного числа
# 4. Как бонусный вариант оформите код в виде функции

# %%
sequence = '2 3 1 5 9 22 3 5'

# %% [markdown]
# Может пригодиться:

# %%
# получить список из строки
sequence.split(' ')
# Out:
# ['2', '3', '1', '5', '9', '22', '3', '5']

# %%
# перевод строки в целое число
int('2')
# Out:
# 2

# %%
# проверка четности
22 % 2 == 0
# Out:
# True

# %% [markdown]
# # Чтение файлов
# Рассматриваем задачу сквозной аналитики. Будем работать с этими файлами:
# - visit_log.csv
# - purchase_log.txt

# %% [markdown]
# ### Способ 1. Делаем все пошагово
# Опции при открытии файлов:
# - 'r' открыть для чтения. Файл при этом не меняется
# - 'w' открыть файл для записи. Файл при этом полностью чистится (!)
# - 'a' открыть файл для добавления. Файл не меняется, все записи добавляются в конец

# %%
# открываем файл для чтения (опция r)
f = open('visit_log.csv', 'r')

# %%
# прочитать одну строчку
f.readline()
# Out:
# 'user_id,source\n'

# %%
# прочитать еще одну
f.readline()
# Out:
# '6450655ae8,other\n'

# %%
# можно и так
next(f)
# Out:
# 'b4ea53e670,other\n'

# %%
# прочитать все содержимое файла в переменную content
content = f.readlines()

# %%
content[:5]
# Out:
# ['0e37347152,other\n',
#  '96064ae9e0,other\n',
#  'e1bd168161,context\n',
#  '71bcf169b4,other\n',
#  'e0aee73c5d,other\n']

# %%
for line in f:
    print(line)
    
    break

# %% [markdown]
# Часто используется конструкция
# ```python
# another_line.strip().split(',')
# ```

# %%
another_line = f.readline()
another_line
# Out:
# ''

# %%
print('Перенос \nстроки')
# Out:
# Перенос
# строки

# %%
# удаляем перенос строки и лишние пробелы
another_line.strip()
# Out:
# ''

# %%
'333  6450655ae8,other  333'.strip(' 3')
# Out:
# '6450655ae8,other'

# %%
# разбиваем столбцы
another_line.strip().split(',')
# Out:
# ['']

# %%
another_line.split(',')
# Out:
# ['']

# %%
f.close()

# %%
# после закрытия не получится прочитать
f.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-f561c2044435> in <module>
#       1 # после закрытия не получится прочитать
# ----> 2 f.readline()
#
# ValueError: I/O operation on closed file.

# %%
# прочитать все строчки файла
f = open('visit_log.csv', 'r')

content = f.readlines()

f.close()

# %%
content[:5]
# Out:
# ['user_id,source\n',
#  '6450655ae8,other\n',
#  'b4ea53e670,other\n',
#  '0e37347152,other\n',
#  '96064ae9e0,other\n']

# %% [markdown]
# ### Упражнение
# Напишите функцию (или просто код), который возвращает список из первых N строк файла purchase_log.csv без записи всего содержимого файла в оперативную память.

# %% [markdown]
# ### Зачем все так сложно?
# Начинаем запись в файл

# %%
f = open('results.csv', 'w')

# %%
f.write('Начинаю запись первой строки...\n')
# Out:
# 32

# %%
f.write('Начинаю запись второй строки...\n')
# Out:
# 32

# %% [markdown]
# Здесь кто-то еще хочет в него записать

# %%
my_friend_results = open('results.csv', 'w')

# %%
my_friend_results.write('Тут еще результаты есть')
# Out:
# 23

# %%
# пишем свой результат
f.close()

# %%
# и наш результат перезатирается
my_friend_results.close()

# %% [markdown]
# ### Контекстный менеджер
# Как обезопасить себя от подобных накладок

# %%
with open('results.csv', 'w') as f:
    f.write('Начинаю запись первой строки...\n')
    f.write('Начинаю запись второй строки...\n')
    
    my_friend_results = open('results.csv', 'w')
    my_friend_results.write('Тут еще результаты есть')
    my_friend_results.close()

# %% [markdown]
# ### Упражнение
# Напишите функцию, которая фильтрует файл visit_log.csv по источнику context и пишет результат в visits_context.csv. Используйте функцию из второго упражнения для проверки результата.

# %% [markdown]
# # Чтение списков и словарей из файла
# Смотрим что в файле purchase_log.txt. Похоже тут не строки, а словари

# %%
with open('purchase_log.txt') as f:
    print([next(f) for x in range(5)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-662848747ce5> in <module>
# ----> 1 with open('purchase_log.txt') as f:
#       2     print([next(f) for x in range(5)])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'purchase_log.txt'

# %%
import json

# %%
# перевод строки в словарь
dict_in_string = '{"a": 1, "b": 2}'

type(json.loads(dict_in_string))
# Out:
# dict

# %%
json.loads(dict_in_string).values()
# Out:
# dict_values([1, 2])

# %%
# перевод строки в список
list_in_string = '[1, 2, 3]'

json.loads(list_in_string)[-1]
# Out:
# 3

# %%
i = 0
with open('purchase_log.txt') as f:
    for line in f:
        line = line.strip()
        
        dict_ = json.loads(line)
        print(dict_, type(dict_))
        
        i += 1
        if i > 5:
            break
# Out:
# {'user_id': 'user_id', 'category': 'category'} <class 'dict'>
# {'user_id': '1840e0b9d4', 'category': 'РџСЂРѕРґСѓРєС‚С‹'} <class 'dict'>
# {'user_id': '4e4f90fcfb', 'category': 'Р\xadР»РµРєС‚СЂРѕРЅРёРєР°'} <class 'dict'>
# {'user_id': 'afea8d72fc', 'category': 'Р\xadР»РµРєС‚СЂРѕРЅРёРєР°'} <class 'dict'>
# {'user_id': '373a6055fe', 'category': 'Р‘С‹С‚РѕРІР°СЏ С‚РµС…РЅРёРєР°'} <class 'dict'>
# {'user_id': '9b2ab046f3', 'category': 'Р\xadР»РµРєС‚СЂРѕРЅРёРєР°'} <class 'dict'>

# %% [markdown]
# ### Упражнение
# 1. Посчитайте распределение количества покупок по категориям в столбце category
# 2. Составьте словарь, в котором для каждого user_id значением будет название категории

# %% [markdown]
# ### Из словаря в строку тоже можно

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
json.dumps(data)
# Out:
# '{"user_id": "1840e0b9d4", "category": "\\u041f\\u0440\\u043e\\u0434\\u0443\\u043a\\u0442\\u044b"}'

# %%
type(json.dumps(data))
# Out:
# str

# %% [markdown]
# # Модуль pickle
# Запись объекта сразу в файл как поток байтов

# %%
import pickle

# %%
data = {'user_id': '1840e0b9d4', 'category': 'Продукты'}

# %%
with open('data.pickle', 'wb') as f:
    pickle.dump(data, f)

# %%
# прочитать объект из такого файла

with open('data.pickle', 'rb') as f:
    dict_ = pickle.load(f)
    
dict_, dict_['user_id']
# Out:
# ({'user_id': '1840e0b9d4', 'category': 'Продукты'}, '1840e0b9d4')

# %% [markdown]
# ### Упражнение
# В файле payments_stat.pickle записана некая статистика платежей пользователей. Посчитайте среднее значение платежа.

# %% [markdown]
# # Каталог пакетов pip (Python Package Index)
# Варианты установки
# 1. С помощью Anaconda Navigator
# 2. В командной строке (Terminal на маке)
# ```bash
# pip install package_name
# ```
# 3. Скачать версию с github и установить вручную
# ```bash
# pip install .
# ```
#
# Пакеты устанавливаются в определенное окружение! Вам пригодится virtualenv

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in c:\conda\lib\site-packages (5.1.2)

# %%
import plotly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-6361d2547ebc> in <module>
# ----> 1 import plotly
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # Простой импорт

# %%
import sys
sys.path

# %%
# добавляем в список библиотек папку libs
sys.path.append('libs')
sys.path

# %%
from useful_codes import CATEGORIES

# %%
CATEGORIES

# %%
from useful_codes import word_count

# %%
# посмотреть документацию функции

# ?word_count

# %%
word_count('Посчитай количество слов в тексте')

# %% [markdown]
# # Домашнее задание
# 1. Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# ```python
# {'1840e0b9d4': 'Продукты', ...}
# ```
#
# 2. Для каждого user_id в файле visit_log.csv добавьте третий столбец с категорией покупки (если покупка была).
#
# 3. Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия на данные:
# - содержимое purchase_log.txt помещается в оперативную память компьютера
# - содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %%
import json

# %%
dictionary_in_f={}

# %%
purchase = open(r'purchase_log.txt','r',  encoding="utf-8")
f=purchase.readlines()
for line in f:
    user_id=list(json.loads(line).values())[0]
    category=list(json.loads(line).values())[1]
    dictionary_in_f[user_id]=category

# %%
dict_of_csv={}

# %%
 with open('visit_log.csv','r') as v:
        for line in v:
            dict_of_csv[line.strip().split(',')[0]] = line.strip().split(',')[1]

# %%
dict_of_csv.values()
# Out:
# dict_values(['source', 'other', 'other', 'other', 'other', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'context', 'other', 'other', 'None', 'other', 'other', 'context', 'context', 'email', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'context', 'context', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'email', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'context', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'context', 'other', 'other', 'context', 'context', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'context', 'context', 'context', 'other', 'other', 'other', 'context', 'other', 'other', 'context', 'email', 'other', 'email', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'email', 'other', 'context', 'other', 'other', 'other', 'context', 'other', 'email', 'context', 'other', 'other', 'other', 'context', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'email', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'context', 'other', 'context', 'email', 'email', 'context', 'other', 'other', 'other', 'other', 'context', 'other', 'None', 'context', 'other', 'other', 'other', 'other', 'other', 'context', 'context', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'email', 'other', 'context', 'other', 'other', 'other', 'other', 'context', 'other', 'context', 'context', 'other', 'other', 'other', 'context', 'context', 'other', 'context', 'other', 'other', 'email', 'context', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'context', 'context', 'context', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'context', 'email', 'other', 'context', 'context', 'email', 'other', 'other', 'other', 'context', 'context', 'other', 'other', 'email', 'other', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'context', 'email', 'other', 'other', 'other', 'context', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'email', 'other', 'context', 'email', 'other', 'other', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'email', 'other', 'other', 'other', 'context', 'other', 'context', 'context', 'context', 'email', 'other', 'other', 'other', 'other', 'other', 'context', 'context', 'other', 'context', 'context', 'other', 'other', 'other', 'other', 'other', 'email', 'other', 'other', 'other', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'email', 'other', 'other', 'other', 'other', 'context', 'context', 'context', 'context', 'other', 'other', 'email', 'other', 'other', 'other', 'other', 'other', 'email', 'other', 'other', 'context', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'other', 'other', 'other', 'email', 'other', 'other', 'context', 'other', 'other', 'context', 'other', 'other', 'other', 'context', 'context', 'other', 'other', 'context', 'context', 'context', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'context', 'other', 'email', ...

# %%
for key, value in dict_of_csv.items():
    try:
        value_csv=dictionary_in_f[key]
        dict_of_csv[key]=[value,value_csv]
    except:
        dict_of_csv[key]=[value,]

# %%
funnel = open('funnel.csv', 'w')

# %%
funnel.write(json.dumps(dict_of_csv))
# Out:
# 6065658

# %%
funnel.close()
